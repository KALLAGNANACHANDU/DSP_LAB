# %% [markdown]
# WAP to swap values of two variables without using third variable ?

# %%
a = 5
b = 10

a, b = b, a

print(f"After swapping: a = {a}, b = {b}")
# Out:
# After swapping: a = 10, b = 5

# %% [markdown]
# Implement a Emplyee management system:
#                                       Add a employee
#                                       Remove a Employee
#                                       Update details of Employee

# %%
class Employee:
    def __init__(self, emp_id, name, position, salary):
        self.emp_id = emp_id
        self.name = name
        self.position = position
        self.salary = salary

    def __str__(self):
        return f"ID: {self.emp_id}, Name: {self.name}, Position: {self.position}, Salary: {self.salary}"

class EmployeeManagementSystem:
    def __init__(self):
        self.employees = {}

    def add_employee(self, emp_id, name, position, salary):
        if emp_id in self.employees:
            print("Employee ID already exists.")
        else:
            self.employees[emp_id] = Employee(emp_id, name, position, salary)
            print("Employee added successfully.")

    def remove_employee(self, emp_id):
        if emp_id in self.employees:
            del self.employees[emp_id]
            print("Employee removed successfully.")
        else:
            print("Employee ID not found.")

    def update_employee(self, emp_id, name=None, position=None, salary=None):
        if emp_id in self.employees:
            if name:
                self.employees[emp_id].name = name
            if position:
                self.employees[emp_id].position = position
            if salary:
                self.employees[emp_id].salary = salary
            print("Employee details updated successfully.")
        else:
            print("Employee ID not found.")

    def display_employees(self):
        if not self.employees:
            print("No employees to display.")
        else:
            for emp in self.employees.values():
                print(emp)

ems = EmployeeManagementSystem()
ems.add_employee(1, "John Doe", "Developer", 50000)
ems.add_employee(2, "Jane Smith", "Manager", 60000)
ems.display_employees()

ems.update_employee(1, salary=55000)
ems.display_employees()

ems.remove_employee(2)
ems.display_employees()
# Out:
# Employee added successfully.
# Employee added successfully.
# ID: 1, Name: John Doe, Position: Developer, Salary: 50000
# ID: 2, Name: Jane Smith, Position: Manager, Salary: 60000
# Employee details updated successfully.
# ID: 1, Name: John Doe, Position: Developer, Salary: 55000
# ID: 2, Name: Jane Smith, Position: Manager, Salary: 60000
# Employee removed successfully.
# ID: 1, Name: John Doe, Position: Developer, Salary: 55000
